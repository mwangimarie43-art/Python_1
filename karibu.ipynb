# %% [markdown]
# <a href="https://colab.research.google.com/github/mwangimarie43-art/Python_1/blob/main/karibu.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=8
print(a)
2+3
# Out:
# 8
# 5

# %%
name="Mary"
print(name)
print(name.lower())
print(name.upper())
age=21
is_student=True
weight=49
print(type(name))
print(type(age))
print(type(is_student))
print(type(weight))

def greet(name):
  print("Hi",name)
greet("Karimi")
# Out:
# Mary
# mary
# MARY
# <class 'str'>
# <class 'int'>
# <class 'bool'>
# <class 'int'>
# Hi Karimi

# %%
nums=[1,2,3,4,5,6]
print(type(nums))
for num in nums:
  if num <= 5:
    print(num)
  else:
   print("max")

print(nums)
print(nums[2])
nums.append(12)
print(nums)
nums.pop()
print(nums)
if num in nums:
  if num%2 ==0 :
    print(num)
  else:
    print("odd")
# Out:
# <class 'list'>
# 1
# 2
# 3
# 4
# 5
# max
# [1, 2, 3, 4, 5, 6]
# 3
# [1, 2, 3, 4, 5, 6, 12]
# [1, 2, 3, 4, 5, 6]
# 6

# %%
def student(name,age):
  if age < 18:
    print("student is underage")
  else:
    return age

  print("My name is ", name, "Am" ,age, "years old")

student("Imani",20)
# Out:
# 20

# %%
import pandas as pd
data={
    "review":["book","excellent","useful"],
    "rating":[3,4,5]
}
df = pd.DataFrame(data)

df.head()
# Out:
#       review  rating
# 0       book       3
# 1  excellent       4
# 2     useful       5

# %%
import pandas as pd

amazon_df = pd.read_csv('/content/AmazonReviews.csv')
display(amazon_df.head(10))
# Out:
#                id       profileName  \
# 0  R2IOYW8GNJDUAZ             G. W.
# 1  R3NY3KXV8N46K7  Owen C. Marshall
# 2  R270DXU8YVGFPX              Umar
# 3  R13Z1BSD70DMKJ               Dan
# 4  R37T2H59DR3WSL            Zerono
# 5  R3G7MCXLOZGDTO          Some Guy
# 6  R2M2AT6AHNOA5V    geekandglitter
# 7  R1HV0O7Q9M36FN                WF
# 8  R19B86UCRHN8C4    Willger Torres
# 9  R32IHODPYQN8CD                N8
#
#                                                 text  \
# 0  So far I've only made it to "for loops" chapte...
# 1  With the lockdown from the global pandemic, I ...
# 2  In embarking on my journey to learn Python, I ...
# 3  Have had this for one day and the cover is alr...
# 4  Wanted to add in a few tips, so beginners don'...
# 5  This is probably one of the best introductory ...
# 6  I am a beginner/intermediate Python programmer...
# 7  First, I just want to say thank you for allowi...
# 8  Está diseñado en un proceso formativo simple. ...
# ...
